# %%
# !pip install cellxgene-census scanpy tiledb pandas --quiet
# !pip install pandas
# !pip install matplotlib
# !pip install numpy
# !pip install scikit-learn
# !pip install scanpy
import scanpy as sc
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for tiledbsoma (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       Checking: C:\Users\14432\AppData\Local\Temp\pip-install-r1zthjgb\tiledbsoma_28eea129918d434480041f95f305fb5c\dist_links\dist\lib\tiledbsoma.dll exists: False
#       Checking: C:\Users\14432\AppData\Local\Temp\pip-install-r1zthjgb\tiledbsoma_28eea129918d434480041f95f305fb5c\dist_links\dist\bin\tiledbsoma.dll exists: False
#       Could not find module 'tiledbsoma.dll' (or one of its dependencies). Try using the full path with constructor syntax.
#       error: [WinError 2] The system cannot find the file specified
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tiledbsoma
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tiledbsoma)
# Requirement already satisfied: pandas in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (1.26.4)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scikit-learn in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: scanpy in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (1.11.3)
# Requirement already satisfied: anndata>=0.8 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.11.4)
# Requirement already satisfied: h5py>=3.7.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (3.14.0)
# Requirement already satisfied: joblib in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.4.2)
# Requirement already satisfied: legacy-api-wrap>=1.4.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.4.1)
# Requirement already satisfied: matplotlib>=3.7.5 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (3.8.4)
# Requirement already satisfied: natsort in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (3.4.1)
# Requirement already satisfied: numba>=0.57.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (25.0)
# Requirement already satisfied: pandas>=1.5.3 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (2.2.1)
# Requirement already satisfied: patsy!=1.0.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5.13 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.5.13)
# Requirement already satisfied: scikit-learn>=1.1.3 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.7.0)
# Requirement already satisfied: scipy<1.16.0,>=1.8.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (1.13.1)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.1.2)
# Requirement already satisfied: statsmodels>=0.14.4 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.14.5)
# Requirement already satisfied: tqdm in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (4.66.5)
# Requirement already satisfied: typing-extensions in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (4.11.0)
# Requirement already satisfied: umap-learn>=0.5.6 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scanpy) (0.5.9.post2)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from anndata>=0.8->scanpy) (1.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.7.5->scanpy) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from numba>=0.57.1->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.5.3->scanpy) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.5.3->scanpy) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.1.3->scanpy) (3.5.0)
# Requirement already satisfied: colorama in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from tqdm->scanpy) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\14432\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as ppyplot
import numpy as np
import requests
import tempfile
import os

# %%
def load_from_url(url):
    response = requests.get(url)
    with tempfile.NamedTemporaryFile(suffix=".h5ad", delete=False) as tmp_file:
        tmp_file.write(response.content)
        tmp_file.flush()
        tmp_path = tmp_file.name
    return sc.read_h5ad(tmp_path)

cereb_url = "https://datasets.cellxgene.cziscience.com/b07a1ded-bf24-48ef-b32b-a58de97b8080.h5ad"
cereb_data = load_from_url(cereb_url)

# %%
cereb_data.obs
# Out:
#                                      orig_cluster orig_sub_cluster  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1            61.0               61
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1            21.0     orig.cl_21_7
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1            42.0     orig.cl_42_1
# SN003_HUM_CS22_CATATTCAGAACAATC-1            15.0     orig.cl_15_9
# SN003_HUM_CS22_TATCAGGCAGACACTT-1            42.0     orig.cl_42_1
# ...                                           ...              ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1         44.0     orig.cl_44_1
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1         40.0               40
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1         24.0               24
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1         22.0     orig.cl_22_2
# SN308_HUM_newborn_CCGGACAAGATACTGA-1         10.0               10
#
#                                      broad_lineage author_cell_type  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1            other              NaN
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1           RL/EGL               GC
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1           RL/NTZ          glut_DN
# SN003_HUM_CS22_CATATTCAGAACAATC-1             glia        astroglia
# SN003_HUM_CS22_TATCAGGCAGACACTT-1           RL/NTZ          glut_DN
# ...                                            ...              ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1          glia        astroglia
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1         other              NaN
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1         other              NaN
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1            VZ      interneuron
# SN308_HUM_newborn_CCGGACAAGATACTGA-1         other              NaN
#
#                                                 dev_state  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                     NaN
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1               GC_diff_1
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1         glut_DN_defined
# SN003_HUM_CS22_CATATTCAGAACAATC-1              progenitor
# SN003_HUM_CS22_TATCAGGCAGACACTT-1         glut_DN_defined
# ...                                                   ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1           progenitor
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                  NaN
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                  NaN
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  interneuron_defined
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                  NaN
#
#                                                       subtype  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                         NaN
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# ...                                                       ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                      NaN
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                      NaN
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                      NaN
#
#                                               precisest_label  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                         NaN
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# ...                                                       ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                      NaN
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                      NaN
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                      NaN
#
#                                              tissue_id  batch  size_factor  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1       HUM 11858 M Cr  SN003      15461.0
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       HUM 11858 M Cr  SN003      13435.0
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       HUM 11858 M Cr  SN003      12756.0
# SN003_HUM_CS22_CATATTCAGAACAATC-1       HUM 11858 M Cr  SN003      11939.0
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       HUM 11858 M Cr  SN003       8966.0
# ...                                                ...    ...          ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1  HUM 2012258 F Cr  SN308        649.0
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  HUM 2012258 F Cr  SN308        648.0
# SN308_HUM_newborn_CCGGACAAGATACTGA-1  HUM 2012258 F Cr  SN308        631.0
#
#                                       ...      tissue_fragment tissue_type  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1     ...  representative part      tissue
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1     ...  representative part      tissue
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1     ...  representative part      tissue
# SN003_HUM_CS22_CATATTCAGAACAATC-1     ...  representative part      tissue
# SN003_HUM_CS22_TATCAGGCAGACACTT-1     ...  representative part      tissue
# ...                                   ...                  ...         ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  ...             fragment      tissue
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1  ...             fragment      tissue
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1  ...             fragment      tissue
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  ...             fragment      tissue
# SN308_HUM_newborn_CCGGACAAGATACTGA-1  ...             fragment      tissue
#
#                                                     cell_type      assay  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                     unknown  10x 3' v2
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1     cerebellar granule cell  10x 3' v2
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1        glutamatergic neuron  10x 3' v2
# SN003_HUM_CS22_CATATTCAGAACAATC-1             macroglial cell  10x 3' v2
# SN003_HUM_CS22_TATCAGGCAGACACTT-1        glutamatergic neuron  10x 3' v2
# ...                                                       ...        ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1          macroglial cell  10x 3' v3
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                  unknown  10x 3' v3
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                  unknown  10x 3' v3
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1              interneuron  10x 3' v3
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                  unknown  10x 3' v3
#
#                                      disease     sex      tissue  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1     normal    male  cerebellum
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1     normal    male  cerebellum
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1     normal    male  cerebellum
# SN003_HUM_CS22_CATATTCAGAACAATC-1     normal    male  cerebellum
# SN003_HUM_CS22_TATCAGGCAGACACTT-1     normal    male  cerebellum
# ...                                      ...     ...         ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  normal  female  cerebellum
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1  normal  female  cerebellum
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1  normal  female  cerebellum
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  normal  female  cerebellum
# SN308_HUM_newborn_CCGGACAAGATACTGA-1  normal  female  cerebellum
#
#                                      self_reported_ethnicity  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                    unknown
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1                    unknown
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1                    unknown
# SN003_HUM_CS22_CATATTCAGAACAATC-1                    unknown
# SN003_HUM_CS22_TATCAGGCAGACACTT-1                    unknown
# ...                                                      ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1                 unknown
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                 unknown
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                 unknown
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1                 unknown
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                 unknown
#
#                                               development_stage  \
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1             Carnegie stage 22
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             Carnegie stage 22
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             Carnegie stage 22
# SN003_HUM_CS22_CATATTCAGAACAATC-1             Carnegie stage 22
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             Carnegie stage 22
# ...                                                         ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  newborn stage (0-28 days)
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1  newborn stage (0-28 days)
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1  newborn stage (0-28 days)
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  newborn stage (0-28 days)
# SN308_HUM_newborn_CCGGACAAGATACTGA-1  newborn stage (0-28 days)
#
#                                       observation_joinid
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1             ^<HOqrQM_&
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             4rT#Zo%kmN
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             Ae=NX|2=hP
# SN003_HUM_CS22_CATATTCAGAACAATC-1             #evBXt&Wl{
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             5o9iRkenv2
# ...                                                  ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1          vQ)zJ^N21%
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1          Qv!GZpNLSa
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1          3(>lQn>{^_
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1          ^g*4_=D1LL
# SN308_HUM_newborn_CCGGACAAGATACTGA-1          WBXPDi>@HS
#
# [180956 rows x 31 columns]

# %%
cereb_data.obs["disease"]
# Out:
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1       normal
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       normal
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       normal
# SN003_HUM_CS22_CATATTCAGAACAATC-1       normal
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       normal
#                                          ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1    normal
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1    normal
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1    normal
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1    normal
# SN308_HUM_newborn_CCGGACAAGATACTGA-1    normal
# Name: disease, Length: 180956, dtype: category
# Categories (4, object): ['acute myocardial infarction', 'heart failure', 'congenital heart disease', 'normal']

# %%
cereb_data.obs["cell_type"]
# Out:
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1                       unknown
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       cerebellar granule cell
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1          glutamatergic neuron
# SN003_HUM_CS22_CATATTCAGAACAATC-1               macroglial cell
# SN003_HUM_CS22_TATCAGGCAGACACTT-1          glutamatergic neuron
#                                                  ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1            macroglial cell
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1                    unknown
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1                    unknown
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1                interneuron
# SN308_HUM_newborn_CCGGACAAGATACTGA-1                    unknown
# Name: cell_type, Length: 180956, dtype: category
# Categories (25, object): ['glioblast', 'neuroblast (sensu Vertebrata)', 'T cell', 'interneuron', ..., 'differentiation-committed oligodendrocyte pre..., 'brain vascular cell', 'unipolar brush cell', 'unknown']

# %%
cereb_data.obs.columns
# Out:
# Index(['orig_cluster', 'orig_sub_cluster', 'broad_lineage', 'author_cell_type',
#        'dev_state', 'subtype', 'precisest_label', 'tissue_id', 'batch',
#        'size_factor', 'donor_id', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type',
#        'is_primary_data', 'author_stage', 'tissue_fragment', 'tissue_type',
#        'cell_type', 'assay', 'disease', 'sex', 'tissue',
#        'self_reported_ethnicity', 'development_stage', 'observation_joinid'],
#       dtype='object')

# %%
cereb_data.obs["tissue_type"]
# Out:
# SN003_HUM_CS22_CTAGCCTGTCAGATAA-1       tissue
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       tissue
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       tissue
# SN003_HUM_CS22_CATATTCAGAACAATC-1       tissue
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       tissue
#                                          ...
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1    tissue
# SN308_HUM_newborn_TAGATCGTCGTAGGGA-1    tissue
# SN308_HUM_newborn_TCGTCCACAAGCGATG-1    tissue
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1    tissue
# SN308_HUM_newborn_CCGGACAAGATACTGA-1    tissue
# Name: tissue_type, Length: 180956, dtype: category
# Categories (1, object): ['tissue']

# %%
sc.pl.highest_expr_genes(cereb_data)
sc.pp.filter_genes(cereb_data, min_cells=300)
sc.pp.filter_cells(cereb_data, min_counts=200)

# %%
print(cereb_data.var)
cereb_data.var["n_cells"]
# Out:
#                  feature_is_filtered     feature_name feature_reference  \
# ENSG00000237094                False  ENSG00000237094    NCBITaxon:9606
# ENSG00000230021                False  ENSG00000230021    NCBITaxon:9606
# ENSG00000248527                False         MTATP6P1    NCBITaxon:9606
# ENSG00000237491                False        LINC01409    NCBITaxon:9606
# ENSG00000228794                False        LINC01128    NCBITaxon:9606
# ...                              ...              ...               ...
# ENSG00000213015                False           ZNF580    NCBITaxon:9606
# ENSG00000234509                False          SOD1-DT    NCBITaxon:9606
# ENSG00000226496                False        LINC00323    NCBITaxon:9606
# ENSG00000275874                False           PICSAR    NCBITaxon:9606
# ENSG00000129009                False             ISLR    NCBITaxon:9606
#
#                 feature_biotype feature_length  \
# ENSG00000237094            gene            183
# ENSG00000230021            gene            818
# ENSG00000248527            gene            681
# ENSG00000237491            gene           1059
# ENSG00000228794            gene           1627
# ...                         ...            ...
# ENSG00000213015            gene           1022
# ENSG00000234509            gene           2233
# ENSG00000226496            gene           2137
# ENSG00000275874            gene            733
# ENSG00000129009            gene           1380
#
#                                        feature_type  n_cells
# ENSG00000237094  transcribed_unprocessed_pseudogene     1800
# ENSG00000230021    transcribed_processed_pseudogene    44552
# ENSG00000248527              unprocessed_pseudogene     9554
# ENSG00000237491                              lncRNA    13605
# ENSG00000228794                              lncRNA     9680
# ...                                             ...      ...
# ENSG00000213015                      protein_coding      303
# ENSG00000234509                              lncRNA      426
# ENSG00000226496                              lncRNA     1116
# ENSG00000275874                              lncRNA      479
# ENSG00000129009                      protein_coding      380
#
# [22659 rows x 7 columns]
# ENSG00000237094     1800
# ENSG00000230021    44552
# ENSG00000248527     9554
# ENSG00000237491    13605
# ENSG00000228794     9680
#                    ...
# ENSG00000213015      303
# ENSG00000234509      426
# ENSG00000226496     1116
# ENSG00000275874      479
# ENSG00000129009      380
# Name: n_cells, Length: 22659, dtype: int32

# %%
sc.pp.filter_cells(cereb_data, min_genes=200)

# %%
sc.pp.pca(cereb_data)
sc.pp.normalize_total(cereb_data, exclude_highly_expressed = True, inplace=True, target_sum = 1e4)

# %%
sc.pp.neighbors(cereb_data, n_neighbors=10, n_pcs=40)
sc.tl.umap(cereb_data)

# %%
sc.pl.umap(cereb_data)

# %%
sc.pl.umap(cereb_data, color="disease")

# %%
sc.pl.umap(cereb_data, color="cell_type")

# %%
nan_values = cereb_data.obs.isnull().any(axis=1)
cereb_data = cereb_data[~nan_values].copy()
cereb_data.obs.columns
# Out:
# Index(['orig_cluster', 'orig_sub_cluster', 'broad_lineage', 'author_cell_type',
#        'dev_state', 'subtype', 'precisest_label', 'tissue_id', 'batch',
#        'size_factor', 'donor_id', 'assay_ontology_term_id',
#        'cell_type_ontology_term_id', 'development_stage_ontology_term_id',
#        'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id',
#        'organism_ontology_term_id', 'sex_ontology_term_id',
#        'tissue_ontology_term_id', 'suspension_type', 'is_primary_data',
#        'author_stage', 'tissue_fragment', 'tissue_type', 'cell_type', 'assay',
#        'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity',
#        'development_stage', 'observation_joinid', 'n_counts', 'n_genes'],
#       dtype='object')

# %%
sc.pl.umap(cereb_data , color=["cell_type", "disease"])

# %%
oligos_subset = cereb_data[cereb_data.obs["cell_type"] == "oligodendrocyte"].copy()

# %%
oligos_subset
# Out:
# AnnData object with n_obs × n_vars = 0 × 22659
#     obs: 'orig_cluster', 'orig_sub_cluster', 'broad_lineage', 'author_cell_type', 'dev_state', 'subtype', 'precisest_label', 'tissue_id', 'batch', 'size_factor', 'donor_id', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'suspension_type', 'is_primary_data', 'author_stage', 'tissue_fragment', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid', 'n_counts', 'n_genes'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'n_cells'
#     uns: 'batch_condition', 'citation', 'default_embedding', 'schema_reference', 'schema_version', 'title', 'pca', 'neighbors', 'umap', 'disease_colors', 'cell_type_colors'
#     obsm: 'X_liger', 'X_umap2d', 'X_umap3d', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
oligos_subset.obs
# Out:
# Empty DataFrame
# Columns: [orig_cluster, orig_sub_cluster, broad_lineage, author_cell_type, dev_state, subtype, precisest_label, tissue_id, batch, size_factor, donor_id, assay_ontology_term_id, cell_type_ontology_term_id, development_stage_ontology_term_id, disease_ontology_term_id, self_reported_ethnicity_ontology_term_id, organism_ontology_term_id, sex_ontology_term_id, tissue_ontology_term_id, suspension_type, is_primary_data, author_stage, tissue_fragment, tissue_type, cell_type, assay, disease, organism, sex, tissue, self_reported_ethnicity, development_stage, observation_joinid, n_counts, n_genes]
# Index: []
#
# [0 rows x 35 columns]

# %%
oligos_subset.obs["cell_type"]
# Out:
# Series([], Name: cell_type, dtype: category
# Categories (0, object): [])

# %%
nan_cells = oligos_subset.obs.isnull().any(axis=1)
nan_cells
# Out:
# Series([], dtype: bool)

# %%
oligos_subset = oligos_subset[~nan_cells].copy()

# %%
oligos_subset.obs
# Out:
# Empty DataFrame
# Columns: [orig_cluster, orig_sub_cluster, broad_lineage, author_cell_type, dev_state, subtype, precisest_label, tissue_id, batch, size_factor, donor_id, assay_ontology_term_id, cell_type_ontology_term_id, development_stage_ontology_term_id, disease_ontology_term_id, self_reported_ethnicity_ontology_term_id, organism_ontology_term_id, sex_ontology_term_id, tissue_ontology_term_id, suspension_type, is_primary_data, author_stage, tissue_fragment, tissue_type, cell_type, assay, disease, organism, sex, tissue, self_reported_ethnicity, development_stage, observation_joinid, n_counts, n_genes]
# Index: []
#
# [0 rows x 35 columns]

# %%
cereb_data.obs
# Out:
#                                      orig_cluster orig_sub_cluster  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1            21.0     orig.cl_21_7
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1            42.0     orig.cl_42_1
# SN003_HUM_CS22_CATATTCAGAACAATC-1            15.0     orig.cl_15_9
# SN003_HUM_CS22_TATCAGGCAGACACTT-1            42.0     orig.cl_42_1
# SN003_HUM_CS22_TACTTGTAGGACATTA-1            38.0     orig.cl_38_0
# ...                                           ...              ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1         65.0               65
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1         21.0     orig.cl_21_1
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1         65.0               65
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1         44.0     orig.cl_44_1
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1         22.0     orig.cl_22_2
#
#                                      broad_lineage author_cell_type  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1           RL/EGL               GC
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1           RL/NTZ          glut_DN
# SN003_HUM_CS22_CATATTCAGAACAATC-1             glia        astroglia
# SN003_HUM_CS22_TATCAGGCAGACACTT-1           RL/NTZ          glut_DN
# SN003_HUM_CS22_TACTTGTAGGACATTA-1             glia        astroglia
# ...                                            ...              ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1      mesoderm           immune
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1        RL/EGL               GC
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1      mesoderm           immune
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1          glia        astroglia
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1            VZ      interneuron
#
#                                                 dev_state  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1               GC_diff_1
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1         glut_DN_defined
# SN003_HUM_CS22_CATATTCAGAACAATC-1              progenitor
# SN003_HUM_CS22_TATCAGGCAGACACTT-1         glut_DN_defined
# SN003_HUM_CS22_TACTTGTAGGACATTA-1              progenitor
# ...                                                   ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1               immune
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1            GC_diff_1
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1               immune
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1           progenitor
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  interneuron_defined
#
#                                                       subtype  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# SN003_HUM_CS22_TACTTGTAGGACATTA-1         progenitor_bipotent
# ...                                                       ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                   T-cell
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1          GC_diff_1_early
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                   T-cell
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
#
#                                               precisest_label  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# SN003_HUM_CS22_TACTTGTAGGACATTA-1         progenitor_bipotent
# ...                                                       ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                   T-cell
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1          GC_diff_1_early
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                   T-cell
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
#
#                                              tissue_id  batch  size_factor  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       HUM 11858 M Cr  SN003      13435.0
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       HUM 11858 M Cr  SN003      12756.0
# SN003_HUM_CS22_CATATTCAGAACAATC-1       HUM 11858 M Cr  SN003      11939.0
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       HUM 11858 M Cr  SN003       8966.0
# SN003_HUM_CS22_TACTTGTAGGACATTA-1       HUM 11858 M Cr  SN003       8543.0
# ...                                                ...    ...          ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  HUM 2012258 F Cr  SN308        678.0
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  HUM 2012258 F Cr  SN308        676.0
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  HUM 2012258 F Cr  SN308        648.0
#
#                                       ...      assay disease      organism  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_CATATTCAGAACAATC-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_TATCAGGCAGACACTT-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_TACTTGTAGGACATTA-1     ...  10x 3' v2  normal  Homo sapiens
# ...                                   ...        ...     ...           ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  ...  10x 3' v3  normal  Homo sapiens
#
#                                          sex      tissue  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       male  cerebellum
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       male  cerebellum
# SN003_HUM_CS22_CATATTCAGAACAATC-1       male  cerebellum
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       male  cerebellum
# SN003_HUM_CS22_TACTTGTAGGACATTA-1       male  cerebellum
# ...                                      ...         ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  female  cerebellum
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  female  cerebellum
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  female  cerebellum
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  female  cerebellum
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  female  cerebellum
#
#                                      self_reported_ethnicity  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1                    unknown
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1                    unknown
# SN003_HUM_CS22_CATATTCAGAACAATC-1                    unknown
# SN003_HUM_CS22_TATCAGGCAGACACTT-1                    unknown
# SN003_HUM_CS22_TACTTGTAGGACATTA-1                    unknown
# ...                                                      ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                 unknown
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1                 unknown
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                 unknown
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1                 unknown
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1                 unknown
#
#                                               development_stage  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             Carnegie stage 22
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             Carnegie stage 22
# SN003_HUM_CS22_CATATTCAGAACAATC-1             Carnegie stage 22
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             Carnegie stage 22
# SN003_HUM_CS22_TACTTGTAGGACATTA-1             Carnegie stage 22
# ...                                                         ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  newborn stage (0-28 days)
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  newborn stage (0-28 days)
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  newborn stage (0-28 days)
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  newborn stage (0-28 days)
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  newborn stage (0-28 days)
#
#                                      observation_joinid n_counts n_genes
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1            4rT#Zo%kmN  13300.0    5410
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1            Ae=NX|2=hP  12695.0    5767
# SN003_HUM_CS22_CATATTCAGAACAATC-1            #evBXt&Wl{  11886.0    5610
# SN003_HUM_CS22_TATCAGGCAGACACTT-1            5o9iRkenv2   8940.0    4464
# SN003_HUM_CS22_TACTTGTAGGACATTA-1            ;<zL88Q@;*   8497.0    4300
# ...                                                 ...      ...     ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1         ;(AUQ^G(gi    672.0     533
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1         ys&=78^e73    674.0     547
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1         WBtx}4n1EF    668.0     534
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1         vQ)zJ^N21%    668.0     503
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1         ^g*4_=D1LL    648.0     526
#
# [82862 rows x 35 columns]

# %%
cereb_data.var
# Out:
#                  feature_is_filtered            feature_name  \
# ENSG00000237094                False      ENSG00000237094.13
# ENSG00000230021                False      ENSG00000230021.10
# ENSG00000248527                False                MTATP6P1
# ENSG00000237491                False               LINC01409
# ENSG00000228794                False               LINC01128
# ...                              ...                     ...
# ENSG00000213015                False  ZNF580_ENSG00000213015
# ENSG00000234509                False                 SOD1-DT
# ENSG00000226496                False               LINC00323
# ENSG00000275874                False                  PICSAR
# ENSG00000129009                False    ISLR_ENSG00000129009
#
#                 feature_reference feature_biotype feature_length  \
# ENSG00000237094    NCBITaxon:9606            gene            183
# ENSG00000230021    NCBITaxon:9606            gene            818
# ENSG00000248527    NCBITaxon:9606            gene            681
# ENSG00000237491    NCBITaxon:9606            gene           1059
# ENSG00000228794    NCBITaxon:9606            gene           1627
# ...                           ...             ...            ...
# ENSG00000213015    NCBITaxon:9606            gene           1022
# ENSG00000234509    NCBITaxon:9606            gene           2233
# ENSG00000226496    NCBITaxon:9606            gene           2137
# ENSG00000275874    NCBITaxon:9606            gene            733
# ENSG00000129009    NCBITaxon:9606            gene           1380
#
#                                        feature_type  n_cells
# ENSG00000237094  transcribed_unprocessed_pseudogene     1800
# ENSG00000230021    transcribed_processed_pseudogene    44552
# ENSG00000248527              unprocessed_pseudogene     9554
# ENSG00000237491                              lncRNA    13605
# ENSG00000228794                              lncRNA     9680
# ...                                             ...      ...
# ENSG00000213015                      protein_coding      303
# ENSG00000234509                              lncRNA      426
# ENSG00000226496                              lncRNA     1116
# ENSG00000275874                              lncRNA      479
# ENSG00000129009                      protein_coding      380
#
# [22659 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.inspection import permutation_importance

# %%
X_data = cereb_data.X
y_label = cereb_data.obs["disease"]
X_train, X_test, y_train, y_test = train_test_split(X_data, y_label, random_state=12345, train_size=0.35, stratify=y_label)
model = LogisticRegression(multi_class='multinomial', solver='lbfgs', C=0.1, class_weight="balanced", max_iter=10000)
model.fit(X_train, y_train)
pred = model.predict(X_test)
acc_score = accuracy_score(y_test, pred)

print(acc_score)
# Out:
# /users/imbahndu/.local/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# 0.9924249456935444

# %%
conf_matrix = confusion_matrix(y_test, pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[  595     1     5    23]
#  [    0  2828     0    37]
#  [    5     0   676    38]
#  [  162    51    86 49354]]

# %%
class_report = classification_report(y_test, pred)
print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#                              precision    recall  f1-score   support
#
# acute myocardial infarction       0.78      0.95      0.86       624
#    congenital heart disease       0.98      0.99      0.98      2865
#               heart failure       0.88      0.94      0.91       719
#                      normal       1.00      0.99      1.00     49653
#
#                    accuracy                           0.99     53861
#                   macro avg       0.91      0.97      0.94     53861
#                weighted avg       0.99      0.99      0.99     53861

# %%
# !pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: pandas>=1.2 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: pillow>=8 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: cycler>=0.10 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /oscar/home/imbahndu/.local/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /users/imbahndu/.local/lib/python3.9/site-packages
# sysconfig: /users/imbahndu/.local/lib64/python3.9/site-packages
# WARNING: Additional context:
# user = True
# home = None
# root = None
# prefix = None

# %%
sfm = SelectFromModel(model, prefit=True, threshold="mean", max_features=716)  
X_train_selected = sfm.transform(X_train)
X_test_selected = sfm.transform(X_test)

print(f"Selected {X_train_selected.shape[1]} features out of {X_train.shape[1]}")

selected_mask = sfm.get_support()  
selected_genes = cereb_data.var_names[selected_mask]  
print(selected_genes)
print(type(selected_genes))

selected = list(selected_genes)

# Extract gene names
selected_gene_symbols = cereb_data.var.loc[selected_genes, "feature_name"]

print(selected_gene_symbols)
# Out:
# Selected 716 features out of 22659
# Index(['ENSG00000078369', 'ENSG00000171735', 'ENSG00000049246',
#        'ENSG00000142599', 'ENSG00000048707', 'ENSG00000189337',
#        'ENSG00000162545', 'ENSG00000142676', 'ENSG00000117632',
#        'ENSG00000117713',
#        ...
#        'ENSG00000280441', 'ENSG00000160307', 'ENSG00000131095',
#        'ENSG00000019582', 'ENSG00000173391', 'ENSG00000144230',
#        'ENSG00000107317', 'ENSG00000100362', 'ENSG00000168329',
#        'ENSG00000196126'],
#       dtype='object', length=716)
# <class 'pandas.core.indexes.base.Index'>
# ENSG00000078369      GNB1_ENSG00000078369
# ENSG00000171735    CAMTA1_ENSG00000171735
# ENSG00000049246      PER3_ENSG00000049246
# ENSG00000142599      RERE_ENSG00000142599
# ENSG00000048707    VPS13D_ENSG00000048707
#                             ...
# ENSG00000144230     GPR17_ENSG00000144230
# ENSG00000107317     PTGDS_ENSG00000107317
# ENSG00000100362     PVALB_ENSG00000100362
# ENSG00000168329    CX3CR1_ENSG00000168329
# ENSG00000196126                  HLA-DRB1
# Name: feature_name, Length: 716, dtype: category
# Categories (22659, object): ['A1BG-AS1', 'A1CF_ENSG00000148584', 'A2M-AS1', 'A2ML1-AS1', ..., 'ZYG11B_ENSG00000162378', 'ZYX_ENSG00000159840', 'ZZEF1_ENSG00000074755', 'ZZZ3_ENSG00000036549']

# %%
#Done this for both datasets --> accuracy making me to doubt though
new_combined = cereb_data[:, selected_genes].copy()

# %%
new_combined.obs
# Out:
#                                      orig_cluster orig_sub_cluster  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1            21.0     orig.cl_21_7
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1            42.0     orig.cl_42_1
# SN003_HUM_CS22_CATATTCAGAACAATC-1            15.0     orig.cl_15_9
# SN003_HUM_CS22_TATCAGGCAGACACTT-1            42.0     orig.cl_42_1
# SN003_HUM_CS22_TACTTGTAGGACATTA-1            38.0     orig.cl_38_0
# ...                                           ...              ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1         65.0               65
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1         21.0     orig.cl_21_1
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1         65.0               65
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1         44.0     orig.cl_44_1
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1         22.0     orig.cl_22_2
#
#                                      broad_lineage author_cell_type  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1           RL/EGL               GC
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1           RL/NTZ          glut_DN
# SN003_HUM_CS22_CATATTCAGAACAATC-1             glia        astroglia
# SN003_HUM_CS22_TATCAGGCAGACACTT-1           RL/NTZ          glut_DN
# SN003_HUM_CS22_TACTTGTAGGACATTA-1             glia        astroglia
# ...                                            ...              ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1      mesoderm           immune
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1        RL/EGL               GC
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1      mesoderm           immune
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1          glia        astroglia
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1            VZ      interneuron
#
#                                                 dev_state  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1               GC_diff_1
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1         glut_DN_defined
# SN003_HUM_CS22_CATATTCAGAACAATC-1              progenitor
# SN003_HUM_CS22_TATCAGGCAGACACTT-1         glut_DN_defined
# SN003_HUM_CS22_TACTTGTAGGACATTA-1              progenitor
# ...                                                   ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1               immune
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1            GC_diff_1
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1               immune
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1           progenitor
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  interneuron_defined
#
#                                                       subtype  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# SN003_HUM_CS22_TACTTGTAGGACATTA-1         progenitor_bipotent
# ...                                                       ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                   T-cell
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1          GC_diff_1_early
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                   T-cell
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
#
#                                               precisest_label  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             GC_diff_1_early
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             glut_DN_ventral
# SN003_HUM_CS22_CATATTCAGAACAATC-1     progenitor_VZ_posterior
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             glut_DN_ventral
# SN003_HUM_CS22_TACTTGTAGGACATTA-1         progenitor_bipotent
# ...                                                       ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                   T-cell
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1          GC_diff_1_early
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                   T-cell
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1     progenitor_gliogenic
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1           interneuron_PL
#
#                                              tissue_id  batch  size_factor  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       HUM 11858 M Cr  SN003      13435.0
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       HUM 11858 M Cr  SN003      12756.0
# SN003_HUM_CS22_CATATTCAGAACAATC-1       HUM 11858 M Cr  SN003      11939.0
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       HUM 11858 M Cr  SN003       8966.0
# SN003_HUM_CS22_TACTTGTAGGACATTA-1       HUM 11858 M Cr  SN003       8543.0
# ...                                                ...    ...          ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  HUM 2012258 F Cr  SN308        678.0
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  HUM 2012258 F Cr  SN308        676.0
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  HUM 2012258 F Cr  SN308        670.0
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  HUM 2012258 F Cr  SN308        648.0
#
#                                       ...      assay disease      organism  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_CATATTCAGAACAATC-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_TATCAGGCAGACACTT-1     ...  10x 3' v2  normal  Homo sapiens
# SN003_HUM_CS22_TACTTGTAGGACATTA-1     ...  10x 3' v2  normal  Homo sapiens
# ...                                   ...        ...     ...           ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  ...  10x 3' v3  normal  Homo sapiens
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  ...  10x 3' v3  normal  Homo sapiens
#
#                                          sex      tissue  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1       male  cerebellum
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1       male  cerebellum
# SN003_HUM_CS22_CATATTCAGAACAATC-1       male  cerebellum
# SN003_HUM_CS22_TATCAGGCAGACACTT-1       male  cerebellum
# SN003_HUM_CS22_TACTTGTAGGACATTA-1       male  cerebellum
# ...                                      ...         ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  female  cerebellum
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  female  cerebellum
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  female  cerebellum
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  female  cerebellum
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  female  cerebellum
#
#                                      self_reported_ethnicity  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1                    unknown
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1                    unknown
# SN003_HUM_CS22_CATATTCAGAACAATC-1                    unknown
# SN003_HUM_CS22_TATCAGGCAGACACTT-1                    unknown
# SN003_HUM_CS22_TACTTGTAGGACATTA-1                    unknown
# ...                                                      ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1                 unknown
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1                 unknown
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1                 unknown
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1                 unknown
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1                 unknown
#
#                                               development_stage  \
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1             Carnegie stage 22
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1             Carnegie stage 22
# SN003_HUM_CS22_CATATTCAGAACAATC-1             Carnegie stage 22
# SN003_HUM_CS22_TATCAGGCAGACACTT-1             Carnegie stage 22
# SN003_HUM_CS22_TACTTGTAGGACATTA-1             Carnegie stage 22
# ...                                                         ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1  newborn stage (0-28 days)
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1  newborn stage (0-28 days)
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1  newborn stage (0-28 days)
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1  newborn stage (0-28 days)
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1  newborn stage (0-28 days)
#
#                                      observation_joinid n_counts n_genes
# SN003_HUM_CS22_CCCTCCTTCCGATATG-1            4rT#Zo%kmN  13300.0    5410
# SN003_HUM_CS22_CGGCTAGTCTGCCAGG-1            Ae=NX|2=hP  12695.0    5767
# SN003_HUM_CS22_CATATTCAGAACAATC-1            #evBXt&Wl{  11886.0    5610
# SN003_HUM_CS22_TATCAGGCAGACACTT-1            5o9iRkenv2   8940.0    4464
# SN003_HUM_CS22_TACTTGTAGGACATTA-1            ;<zL88Q@;*   8497.0    4300
# ...                                                 ...      ...     ...
# SN308_HUM_newborn_CTCTCAGCAGGTCAAG-1         ;(AUQ^G(gi    672.0     533
# SN308_HUM_newborn_TAACTTCCATCGCCTT-1         ys&=78^e73    674.0     547
# SN308_HUM_newborn_CGAAGTTCACTGCACG-1         WBtx}4n1EF    668.0     534
# SN308_HUM_newborn_CATCCGTGTAGGTTTC-1         vQ)zJ^N21%    668.0     503
# SN308_HUM_newborn_AGTAGCTAGATCGCTT-1         ^g*4_=D1LL    648.0     526
#
# [82862 rows x 35 columns]

# %%
temp_cereb_path = os.path.join(tempfile.gettempdir(), "cereb_combined.h5ad")
new_combined.write(temp_cereb_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_combined.var
#
# NameError: name 'new_combined' is not defined
